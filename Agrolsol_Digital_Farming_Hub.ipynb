# %%
# %%html
# <!doctype html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>AgroSol - Smart Farming Platform | Disease Detection & Tool Rental</title>
#     <meta name="description" content="AgroSol helps farmers identify plant diseases through AI-powered image analysis and rent agricultural equipment. Smart farming made simple." />
#     <meta name="author" content="AgroSol" />
#
#     <meta property="og:title" content="AgroSol - Smart Farming Platform" />
#     <meta property="og:description" content="AI-powered plant disease detection and agricultural tool rental marketplace for modern farmers" />
#     <meta property="og:type" content="website" />
#     <meta property="og:image" content="https://lovable.dev/opengraph-image-p98pqg.png" />
#
#     <meta name="twitter:card" content="summary_large_image" />
#     <meta name="twitter:site" content="@lovable_dev" />
#     <meta name="twitter:image" content="https://lovable.dev/opengraph-image-p98pqg.png" />
#
#     <style>
#       @tailwind base;
#
#       :root {
#         --background: 0 0% 100%;
#         --foreground: 120 40% 15%;
#
#         --card: 0 0% 100%;
#         --card-foreground: 120 40% 15%;
#
#         --popover: 0 0% 100%;
#         --popover-foreground: 120 40% 15%;
#
#         --primary: 100 60% 25%;
#         --primary-foreground: 0 0% 100%;
#
#         --secondary: 90 60% 65%;
#         --secondary-foreground: 120 40% 15%;
#
#         --muted: 100 25% 98%;
#         --muted-foreground: 120 15% 50%;
#
#         --accent: 100 25% 95%;
#         --accent-foreground: 120 40% 15%;
#
#         --destructive: 0 84.2% 60.2%;
#         --destructive-foreground: 0 0% 100%;
#
#         --border: 100 20% 88%;
#         --input: 100 20% 88%;
#         --ring: 100 60% 25%;
#
#         --radius: 0.75rem;
#
#         --gradient-hero: linear-gradient(135deg, hsl(100 60% 25%) 0%, hsl(90 60% 65%) 100%);
#         --gradient-card: linear-gradient(180deg, hsl(0 0% 100%) 0%, hsl(100 25% 98%) 100%);
#
#         --shadow-soft: 0 4px 20px -2px hsl(100 60% 25% / 0.1);
#         --shadow-medium: 0 8px 30px -4px hsl(100 60% 25% / 0.15);
#
#         --transition-smooth: all 0.3s cubic-bezier(0.4, 0, 0.2, 1);
#
#         --sidebar-background: 0 0% 98%;
#         --sidebar-foreground: 120 40% 15%;
#         --sidebar-primary: 100 60% 25%;
#         --sidebar-primary-foreground: 0 0% 100%;
#         --sidebar-accent: 100 25% 95%;
#         --sidebar-accent-foreground: 120 40% 15%;
#         --sidebar-border: 100 20% 88%;
#         --sidebar-ring: 100 60% 25%;
#       }
#
#       .dark {
#         --background: 120 25% 8%;
#         --foreground: 0 0% 98%;
#
#         --card: 120 20% 12%;
#         --card-foreground: 0 0% 98%;
#
#         --popover: 120 20% 12%;
#         --popover-foreground: 0 0% 98%;
#
#         --primary: 90 60% 65%;
#         --primary-foreground: 120 40% 15%;
#
#         --secondary: 32 55% 45%;
#         --secondary-foreground: 0 0% 100%;
#
#         --muted: 120 20% 18%;
#         --muted-foreground: 100 15% 70%;
#
#         --accent: 100 50% 35%;
#         --accent-foreground: 0 0% 100%;
#
#         --destructive: 0 62.8% 30.6%;
#         --destructive-foreground: 0 0% 100%;
#
#         --border: 120 20% 18%;
#         --input: 120 20% 18%;
#         --ring: 90 60% 65%;
#
#         --gradient-hero: linear-gradient(135deg, hsl(100 50% 20%) 0%, hsl(90 60% 45%) 100%);
#         --gradient-card: linear-gradient(180deg, hsl(120 20% 12%) 0%, hsl(120 20% 15%) 100%);
#
#         --sidebar-background: 120 20% 10%;
#         --sidebar-foreground: 0 0% 98%;
#         --sidebar-primary: 90 60% 65%;
#         --sidebar-primary-foreground: 120 40% 15%;
#         --sidebar-accent: 120 20% 18%;
#         --sidebar-accent-foreground: 0 0% 98%;
#         --sidebar-border: 120 20% 18%;
#         --sidebar-ring: 90 60% 65%;
#       }
#       }
#
#       @layer base {
#         * {
#           @apply border-border;
#         }
#
#         body {
#           @apply bg-background text-foreground;
#         }
#       }
#     </style>
#   </head>
#
#   <body>
#     <div id="root"></div>
#     <script type="module" src="/src/main.tsx"></script>
#   </body>
# </html>
# Out:
# <!doctype html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>AgroSol - Smart Farming Platform | Disease Detection & Tool Rental</title>
#     <meta name="description" content="AgroSol helps farmers identify plant diseases through AI-powered image analysis and rent agricultural equipment. Smart farming made simple." />
#     <meta name="author" content="AgroSol" />
#
#     <meta property="og:title" content="AgroSol - Smart Farming Platform" />
#     <meta property="og:description" content="AI-powered plant disease detection and agricultural tool rental marketplace for modern farmers" />
#     <meta property="og:type" content="website" />
#     <meta property="og:image" content="https://lovable.dev/opengraph-image-p98pqg.png" />
#
#     <meta name="twitter:card" content="summary_large_image" />
#     <meta name="twitter:site" content="@lovable_dev" />
# ...
